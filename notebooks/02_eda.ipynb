# %%
from pathlib import Path
print("cwd:", Path.cwd())
print("data here?", (Path.cwd() / "data" / "processed" / "transactions.parquet").exists())
print("data up one?", (Path.cwd().parent / "data" / "processed" / "transactions.parquet").exists())
# Out:
# cwd: f:\hnm-fashion
# data here? False
# data up one? False
